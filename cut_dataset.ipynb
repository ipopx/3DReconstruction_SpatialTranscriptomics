 'ENSMUSG00000027584',
 'ENSMUSG00000049112',
 'ENSMUSG00000031284',
 'ENSMUSG00000034755',
 'ENSMUSG00000029231',
 'ENSMUSG00000031870',
 'ENSMUSG00000024197',
 'ENSMUSG00000045731',
 'ENSMUSG00000095139',
 'ENSMUSG00000005268',
 'ENSMUSG00000041046',
 'ENSMUSG00000026360',
 'ENSMUSG00000026678',
 'ENSMUSG00000017144',
 'ENSMUSG00000034009',
 'ENSMUSG00000021337',
 'ENSMUSG00000048163',
 'ENSMUSG00000028780',
 'ENSMUSG00000021451',
 'ENSMUSG00000051029',
 'ENSMUSG00000037411',
 'ENSMUSG00000019970',
 'ENSMUSG00000024737',
 'ENSMUSG00000030500',
 'ENSMUSG00000070570',
 'ENSMUSG00000019935',
 'ENSMUSG00000025094',
 'ENSMUSG00000030237',
 'ENSMUSG00000076431',
 'ENSMUSG00000051910',
 'ENSMUSG00000024176',
 'ENSMUSG00000068859',
 'ENSMUSG00000056296',
 'ENSMUSG00000026452',
 'ENSMUSG00000024261',
 'ENSMUSG00000031255',
 'ENSMUSG00000030043',
 'ENSMUSG00000028172',
 'ENSMUSG00000034640',
 'ENSMUSG00000042757',
 'ENSMUSG00000017386',
 'ENSMUSG00000038760',
 'ENSMUSG00000051747',
 'ENSMUSG00000034714',
 'ENSMUSG00000024256',
 'ENSMUSG00000021647',
 'ENSMUSG00000032532',
 'ENSMUSG00000049796',
 'ENSMUSG00000024907',
 'ENSMUSG00000015812',
 'ENSMUSG00000041607',
 'ENSMUSG00000067786',
 'ENSMUSG00000019890',
 'ENSMUSG00000027301',
 'ENSMUSG00000045573',
 'ENSMUSG00000050711',
 'ENSMUSG00000042045',
 'ENSMUSG00000004366',
 'ENSMUSG00000061762',
 'ENSMUSG00000025400',
 'ENSMUSG00000000214',
 'ENSMUSG00000005892',
 'ENSMUSG00000044988',
 'ENSMUSG00000037428']

# %%
import cellxgene_census
import pandas as pd

collection_id = "0cca8620-8dee-45d0-aef5-23f032a5cf09"

with cellxgene_census.open_soma() as census:
    datasets = census["census_info"]["datasets"].read().concat().to_pandas()

df = datasets[datasets["collection_id"] == collection_id]
print(df[["dataset_id", "dataset_title"]])
# Out:
# The "stable" release is currently 2025-11-08. Specify 'census_version="2025-11-08"' in future calls to open_soma() to ensure data consistency.
# Empty DataFrame
# Columns: [dataset_id, dataset_title]
# Index: []

# %%
import cellxgene_census
import scanpy as sc

my_genes = list(set(starmap_genes) | set(merfish_genes))
animal1_anterior_id = '8f76a05d-c780-4564-a1d8-ac3dc9b9bf70'

with cellxgene_census.open_soma() as census:
    adata = cellxgene_census.get_anndata(
        census = census,
        organism = "Mus musculus", 
        # Note the extra quotes around the variable in the filter strings
        var_value_filter = f"feature_id in {my_genes}", 
        obs_value_filter = f"dataset_id == '{animal1_anterior_id}'"
    )
# Out:
# The "stable" release is currently 2025-11-08. Specify 'census_version="2025-11-08"' in future calls to open_soma() to ensure data consistency.
# /home/ipopx/miniconda3/envs/scvi_env/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ipopx/miniconda3/envs/scvi_env/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata.write_h5ad("animal1_anterior.h5ad")
print(f"Successfully saved {adata.n_vars} genes for {adata.n_obs} cells.")
# Out:
# Successfully saved 176 genes for 0 cells.
