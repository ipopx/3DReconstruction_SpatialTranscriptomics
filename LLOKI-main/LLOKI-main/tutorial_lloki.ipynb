# %%
import argparse

from lloki.cae.run_lloki_cae import run_lloki_cae
from lloki.fp.run_lloki_fp import run_lloki_fp

import warnings
warnings.filterwarnings('ignore')

import os
import zipfile
import gdown

default_values = {
    'data_dir': "data/input_slices",
    'output_dir': "output",
    'model_dir': "external/scgpt",
    'reference_data_path': "data/reference_data/scref_full.h5ad",
    'k': 40,
    'iter': 40,
    'alpha': 0.5,
    'seed': 0,
    'device': "cuda",
    "npl_num_neighbors": 30
}

# Step 2: Convert the dictionary to an argparse.Namespace
args = argparse.Namespace(**default_values)
# Out:
# /home/ipopx/miniconda3/envs/lloki/lib/python3.10/site-packages/scgpt/model/model.py:21: UserWarning: flash_attn is not installed
#   warnings.warn("flash_attn is not installed")
# /home/ipopx/miniconda3/envs/lloki/lib/python3.10/site-packages/scgpt/model/multiomic_model.py:19: UserWarning: flash_attn is not installed
#   warnings.warn("flash_attn is not installed")
# /home/ipopx/miniconda3/envs/lloki/lib/python3.10/site-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /home/ipopx/miniconda3/envs/lloki/lib/python3.10/site-packages/torchtext/utils.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)

# %%
data_dir = "data/input_slices"
data_parent_dir = os.path.dirname(data_dir)
os.makedirs(data_parent_dir, exist_ok=True)

zip_path = os.path.join(data_parent_dir, "h5ads_all.zip")
gdown.download(id="1NE6SXmJcEKT4mhVMAO49-Y3KMCNoHOmM", output=zip_path, quiet=False)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(data_parent_dir)

print(f"Unzipped into: {data_parent_dir}")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1NE6SXmJcEKT4mhVMAO49-Y3KMCNoHOmM
# From (redirected): https://drive.google.com/uc?id=1NE6SXmJcEKT4mhVMAO49-Y3KMCNoHOmM&confirm=t&uuid=213aace4-e52e-4c0a-ac56-5e8e2373375b
# To: /home/ipopx/research_ds/3DReconstruction_SpatialTranscriptomics/LLOKI-main/LLOKI-main/data/h5ads_all.zip
#   4%|▍         | 106M/2.39G [00:47<11:47, 3.23MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 os.makedirs(data_parent_dir, exist_ok=True)
#       5 zip_path = os.path.join(data_parent_dir, "h5ads_all.zip")
# ----> 6 gdown.download(id="1NE6SXmJcEKT4mhVMAO49-Y3KMCNoHOmM", output=zip_path, quiet=False)
#       8 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#       9     zip_ref.extractall(data_parent_dir)
#
# File ~/miniconda3/envs/lloki/lib/python3.10/site-packages/gdown/download.py:398, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress)
#     396 t_start = time.time()
#     397 downloaded = 0
# --> 398 for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#     399     f.write(chunk)
#     400     downloaded += len(chunk)
#
# File ~/miniconda3/envs/lloki/lib/python3.10/site-packages/requests/models.py:822, in Response.iter_content.<locals>.generate()
#     820 if hasattr(self.raw, "stream"):
#     821     try:
# --> 822         yield from self.raw.stream(chunk_size, decode_content=True)
#     823     except ProtocolError as e:
#     824         raise ChunkedEncodingError(e)
#
# File ~/miniconda3/envs/lloki/lib/python3.10/site-packages/urllib3/response.py:1257, in HTTPResponse.stream(self, amt, decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
# -> 1257         data = self.read(amt=amt, decode_content=decode_content)
#    1259         if data:
#    1260             yield data
#
# File ~/miniconda3/envs/lloki/lib/python3.10/site-packages/urllib3/response.py:1112, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1109     if len(self._decoded_buffer) >= amt:
#    1110         return self._decoded_buffer.get(amt)
# -> 1112 data = self._raw_read(amt)
#    1114 flush_decoder = amt is None or (amt != 0 and not data)
#    1116 if (
#    1117     not data
#    1118     and len(self._decoded_buffer) == 0
#    1119     and not (self._decoder and self._decoder.has_unconsumed_tail)
#    1120 ):
#
# File ~/miniconda3/envs/lloki/lib/python3.10/site-packages/urllib3/response.py:1028, in HTTPResponse._raw_read(self, amt, read1)
#    1025 fp_closed = getattr(self._fp, "closed", False)
#    1027 with self._error_catcher():
# -> 1028     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1029     if amt is not None and amt != 0 and not data:
#    1030         # Platform-specific: Buggy versions of Python.
#    1031         # Close the connection when no data is returned
#    (...)
#    1036         # not properly close the connection in all cases. There is
#    1037         # no harm in redundantly calling close.
#    1038         self._fp.close()
#
# File ~/miniconda3/envs/lloki/lib/python3.10/site-packages/urllib3/response.py:1011, in HTTPResponse._fp_read(self, amt, read1)
#    1008     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1009 else:
#    1010     # StringIO doesn't like amt=None
# -> 1011     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/miniconda3/envs/lloki/lib/python3.10/http/client.py:471, in HTTPResponse.read(self, amt)
#     468 if self.length is not None and amt > self.length:
#     469     # clip the read to the "end of response"
#     470     amt = self.length
# --> 471 s = self.fp.read(amt)
#     472 if not s and amt:
#     473     # Ideally, we would raise IncompleteRead if the content-length
#     474     # wasn't satisfied, but it might break compatibility.
#     475     self._close_conn()
#
# File ~/miniconda3/envs/lloki/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~/miniconda3/envs/lloki/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/lloki/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:
#   4%|▍         | 106M/2.39G [00:59<11:47, 3.23MB/s]

# %%
data_dir = "data/input_slices"
data_parent_dir = os.path.dirname(data_dir)

# If the data_dir doesn't exist, download and extract
if not os.path.exists(data_dir):
    os.makedirs(data_parent_dir, exist_ok=True)

    zip_path = os.path.join(data_parent_dir, "h5ads_all.zip")
    gdown.download(id="1NE6SXmJcEKT4mhVMAO49-Y3KMCNoHOmM", output=zip_path, quiet=False)

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(data_parent_dir)

    print(f"Unzipped into: {data_parent_dir}")
else:
    print(f"Found existing input slices: {data_dir}")

# %%
run_lloki_fp(args)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 run_lloki_fp(args)
#
# File ~/research_ds/3DReconstruction_SpatialTranscriptomics/LLOKI-main/LLOKI-main/lloki/fp/run_lloki_fp.py:21, in run_lloki_fp(args)
#      18 torch.set_num_threads(3)
#      20 # Load reference data for propagation
# ---> 21 adata_scrna = sc.read_h5ad(args.reference_data_path)  # Update path
#      23 # Process each .h5ad file in the data directory
#      24 for h5ad_file in glob.glob(os.path.join(args.data_dir, "*.h5ad")):
#
# File ~/miniconda3/envs/lloki/lib/python3.10/site-packages/anndata/_io/h5ad.py:219, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     211         raise NotImplementedError(
#     212             "Currently only `X` and `raw/X` can be read as sparse."
#     213         )
#     215 rdasp = partial(
#     216     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     217 )
# --> 219 with h5py.File(filename, "r") as f:
#     221     def callback(func, elem_name: str, elem, iospec):
#     222         if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#
# File ~/miniconda3/envs/lloki/lib/python3.10/site-packages/h5py/_hl/files.py:555, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, track_times, **kwds)
#     546     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     547                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     548                      alignment_threshold=alignment_threshold,
#     549                      alignment_interval=alignment_interval,
#     550                      meta_block_size=meta_block_size,
#     551                      **kwds)
#     552     fcpl = make_fcpl(track_order=track_order, track_times=track_times,
#     553                      fs_strategy=fs_strategy, fs_persist=fs_persist,
#     554                      fs_threshold=fs_threshold, fs_page_size=fs_page_size)
# --> 555     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     557 if isinstance(libver, tuple):
#     558     self._libver = libver
#
# File ~/miniconda3/envs/lloki/lib/python3.10/site-packages/h5py/_hl/files.py:232, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     230     if swmr:
#     231         flags |= h5f.ACC_SWMR_READ
# --> 232     fid = h5f.open(name, flags, fapl=fapl)
#     233 elif mode == 'r+':
#     234     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'data/reference_data/scref_full.h5ad', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
run_lloki_cae(args)
